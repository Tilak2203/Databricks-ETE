# %%
df = spark.read.table("databricks_ete.bronze.regions")
display(df)

# %%
df = df.drop("_rescued_data")

# %%
display(df)

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save("abfss://silver@databricksetestorage2003.dfs.core.windows.net/regions")

# %%
df = spark.read.format("delta")\
    .load("abfss://silver@databricksetestorage2003.dfs.core.windows.net/products")
display(df)
